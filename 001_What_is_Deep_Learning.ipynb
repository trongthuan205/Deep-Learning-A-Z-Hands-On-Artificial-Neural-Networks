# %% [markdown]
# <a href="https://colab.research.google.com/github/trongthuan205/Deep-Learning-A-Z-Hands-On-Artificial-Neural-Networks/blob/master/001_What_is_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1 - Data Preprocessing

# %%
#Iimporting library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Importing  dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:,3:13].values
y = dataset.iloc[:,13].values

# %%
len(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8f70883cce9f> in <module>()
# ----> 1 len(dataset)
#
# NameError: name 'dataset' is not defined

# %%
#Encoding categorical dataset
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder 
from sklearn.compose import ColumnTransformer
le = LabelEncoder() 
X[:,1]= le.fit_transform(X[:,1]) 
X[:,2]= le.fit_transform(X[:,2])
X = np.array(columnTransformer.fit_transform(X))

# %%
#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# # Part 2: Make the ANN

# %%
#Importing the Keras libraries and package
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu', input_dim = 12))
    classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu'))
    classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'] )
    return classifier

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %%
classifier = KerasClassifier(build_fn = build_classifier)

# %%
parameters = {'batch_size': [25,32],
              'epochs': [100,500],
              'optimizer': ['Adam', 'RMSprop']}
              #'optimizer': ['adam','rmsprop']}

# %%
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10)

# %%
grid_search = grid_search.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=12, units=6, kernel_initializer="uniform")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=6, kernel_initializer="uniform")`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   """
# Epoch 1/100
# 7200/7200 [==============================] - 1s 102us/step - loss: 0.5521 - accuracy: 0.7964
# Epoch 2/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4382 - accuracy: 0.7971
# Epoch 3/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4310 - accuracy: 0.7971
# Epoch 4/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4275 - accuracy: 0.7971
# Epoch 5/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4249 - accuracy: 0.7971
# Epoch 6/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4223 - accuracy: 0.7971
# Epoch 7/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4204 - accuracy: 0.8111
# Epoch 8/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4188 - accuracy: 0.8196
# Epoch 9/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4173 - accuracy: 0.8224
# Epoch 10/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4156 - accuracy: 0.8265
# Epoch 11/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4147 - accuracy: 0.8288
# Epoch 12/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4134 - accuracy: 0.8293
# Epoch 13/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4126 - accuracy: 0.8294
# Epoch 14/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4119 - accuracy: 0.8300
# Epoch 15/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4108 - accuracy: 0.8338
# Epoch 16/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4104 - accuracy: 0.8332
# Epoch 17/100
# 7200/7200 [==============================] - 0s 46us/step - loss: 0.4097 - accuracy: 0.8338
# Epoch 18/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.4089 - accuracy: 0.8338
# Epoch 19/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4082 - accuracy: 0.8339
# Epoch 20/100
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.4075 - accuracy: 0.8356
# Epoch 21/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4073 - accuracy: 0.8347
# Epoch 22/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4064 - accuracy: 0.8347
# Epoch 23/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4059 - accuracy: 0.8363
# Epoch 24/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4058 - accuracy: 0.8357
# Epoch 25/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4055 - accuracy: 0.8356
# Epoch 26/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4050 - accuracy: 0.8358
# Epoch 27/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4045 - accuracy: 0.8346
# Epoch 28/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4042 - accuracy: 0.8360
# Epoch 29/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4040 - accuracy: 0.8351
# Epoch 30/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4037 - accuracy: 0.8364
# Epoch 31/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4036 - accuracy: 0.8354
# Epoch 32/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4033 - accuracy: 0.8358
# Epoch 33/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4030 - accuracy: 0.8356
# Epoch 34/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4024 - accuracy: 0.8358
# Epoch 35/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4023 - accuracy: 0.8358
# Epoch 36/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4022 - accuracy: 0.8360
# Epoch 37/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4023 - accuracy: 0.8351
# Epoch 38/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4019 - accuracy: 0.8357
# Epoch 39/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4015 - accuracy: 0.8356
# Epoch 40/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4016 - accuracy: 0.8357
# Epoch 41/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4013 - accuracy: 0.8360
# Epoch 42/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4011 - accuracy: 0.8339
# Epoch 43/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4009 - accuracy: 0.8381
# Epoch 44/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.4011 - accuracy: 0.8351
# Epoch 45/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4011 - accuracy: 0.8379
# Epoch 46/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4009 - accuracy: 0.8354
# Epoch 47/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.4009 - accuracy: 0.8378
# Epoch 48/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4003 - accuracy: 0.8353
# Epoch 49/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4006 - accuracy: 0.8344
# Epoch 50/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4003 - accuracy: 0.8350
# Epoch 51/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4004 - accuracy: 0.8376
# Epoch 52/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4005 - accuracy: 0.8363
# Epoch 53/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4000 - accuracy: 0.8353
# Epoch 54/100
# 7200/7200 [==============================] - 0s 54us/step - loss: 0.4004 - accuracy: 0.8361
# Epoch 55/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3996 - accuracy: 0.8368
# Epoch 56/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4001 - accuracy: 0.8361
# Epoch 57/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3998 - accuracy: 0.8350
# Epoch 58/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3997 - accuracy: 0.8357
# Epoch 59/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3996 - accuracy: 0.8361
# Epoch 60/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3997 - accuracy: 0.8353
# Epoch 61/100
# 7200/7200 [==============================] - 0s 58us/step - loss: 0.3999 - accuracy: 0.8350
# Epoch 62/100
# 7200/7200 [==============================] - 0s 58us/step - loss: 0.3997 - accuracy: 0.8350
# Epoch 63/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3996 - accuracy: 0.8369
# Epoch 64/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3997 - accuracy: 0.8351
# Epoch 65/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3998 - accuracy: 0.8363
# Epoch 66/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3993 - accuracy: 0.8350
# Epoch 67/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3992 - accuracy: 0.8342
# Epoch 68/100
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.3995 - accuracy: 0.8349
# Epoch 69/100
# 7200/7200 [==============================] - 0s 56us/step - loss: 0.3992 - accuracy: 0.8357
# Epoch 70/100
# 7200/7200 [==============================] - 0s 59us/step - loss: 0.3995 - accuracy: 0.8368
# Epoch 71/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3996 - accuracy: 0.8360
# Epoch 72/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3991 - accuracy: 0.8360
# Epoch 73/100
# 7200/7200 [==============================] - 0s 58us/step - loss: 0.3994 - accuracy: 0.8358
# Epoch 74/100
# 7200/7200 [==============================] - 0s 59us/step - loss: 0.3992 - accuracy: 0.8368
# Epoch 75/100
# 7200/7200 [==============================] - 0s 58us/step - loss: 0.3991 - accuracy: 0.8364
# Epoch 76/100
# 7200/7200 [==============================] - 0s 59us/step - loss: 0.3990 - accuracy: 0.8357
# Epoch 77/100
# 7200/7200 [==============================] - 0s 57us/step - loss: 0.3990 - accuracy: 0.8360
# Epoch 78/100
# 7200/7200 [==============================] - 0s 58us/step - loss: 0.3990 - accuracy: 0.8376
# Epoch 79/100
# 7200/7200 [==============================] - 0s 54us/step - loss: 0.3992 - accuracy: 0.8375
# Epoch 80/100
# 7200/7200 [==============================] - 0s 59us/step - loss: 0.3990 - accuracy: 0.8353
# Epoch 81/100
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.3989 - accuracy: 0.8357
# Epoch 82/100
# 7200/7200 [==============================] - 0s 56us/step - loss: 0.3988 - accuracy: 0.8369
# Epoch 83/100
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.3987 - accuracy: 0.8343
# Epoch 84/100
# 7200/7200 [==============================] - 0s 56us/step - loss: 0.3989 - accuracy: 0.8372
# Epoch 85/100
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.3988 - accuracy: 0.8356
# Epoch 86/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3987 - accuracy: 0.8365
# Epoch 87/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3988 - accuracy: 0.8356
# Epoch 88/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3988 - accuracy: 0.8350
# Epoch 89/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3985 - accuracy: 0.8364
# Epoch 90/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3987 - accuracy: 0.8353
# Epoch 91/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3988 - accuracy: 0.8361
# Epoch 92/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3983 - accuracy: 0.8371
# Epoch 93/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3987 - accuracy: 0.8363
# Epoch 94/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3984 - accuracy: 0.8363
# Epoch 95/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3985 - accuracy: 0.8353
# Epoch 96/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3983 - accuracy: 0.8353
# Epoch 97/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3985 - accuracy: 0.8378
# Epoch 98/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3982 - accuracy: 0.8349
# Epoch 99/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3983 - accuracy: 0.8361
# Epoch 100/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3984 - accuracy: 0.8360
# Epoch 1/100
# 7200/7200 [==============================] - 0s 59us/step - loss: 0.5520 - accuracy: 0.7962
# Epoch 2/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4352 - accuracy: 0.7967
# Epoch 3/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4288 - accuracy: 0.7967
# Epoch 4/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4255 - accuracy: 0.7967
# Epoch 5/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4226 - accuracy: 0.7967
# Epoch 6/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4198 - accuracy: 0.7989
# Epoch 7/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4175 - accuracy: 0.8179
# Epoch 8/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.4164 - accuracy: 0.8235
# Epoch 9/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4149 - accuracy: 0.8285
# Epoch 10/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4136 - accuracy: 0.8294
# Epoch 11/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4128 - accuracy: 0.8304
# Epoch 12/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4117 - accuracy: 0.8310
# Epoch 13/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4107 - accuracy: 0.8319
# Epoch 14/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4100 - accuracy: 0.8325
# Epoch 15/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4091 - accuracy: 0.8321
# Epoch 16/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4090 - accuracy: 0.8321
# Epoch 17/100
# 7200/7200 [==============================] - 0s 46us/step - loss: 0.4084 - accuracy: 0.8326
# Epoch 18/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4079 - accuracy: 0.8344
# Epoch 19/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4073 - accuracy: 0.8328
# Epoch 20/100
# 7200/7200 [==============================] - 0s 46us/step - loss: 0.4070 - accuracy: 0.8335
# Epoch 21/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4067 - accuracy: 0.8339
# Epoch 22/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4058 - accuracy: 0.8347
# Epoch 23/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4056 - accuracy: 0.8339
# Epoch 24/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4054 - accuracy: 0.8346
# Epoch 25/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4049 - accuracy: 0.8353
# Epoch 26/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4045 - accuracy: 0.8356
# Epoch 27/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4042 - accuracy: 0.8356
# Epoch 28/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4039 - accuracy: 0.8364
# Epoch 29/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4033 - accuracy: 0.8354
# Epoch 30/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4034 - accuracy: 0.8353
# Epoch 31/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4030 - accuracy: 0.8357
# Epoch 32/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.4028 - accuracy: 0.8360
# Epoch 33/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4029 - accuracy: 0.8361
# Epoch 34/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.4028 - accuracy: 0.8356
# Epoch 35/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4025 - accuracy: 0.8363
# Epoch 36/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4019 - accuracy: 0.8356
# Epoch 37/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4024 - accuracy: 0.8374
# Epoch 38/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4019 - accuracy: 0.8369
# Epoch 39/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4015 - accuracy: 0.8363
# Epoch 40/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4017 - accuracy: 0.8369
# Epoch 41/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4016 - accuracy: 0.8358
# Epoch 42/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4010 - accuracy: 0.8375
# Epoch 43/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4015 - accuracy: 0.8375
# Epoch 44/100
# 7200/7200 [==============================] - 0s 46us/step - loss: 0.4010 - accuracy: 0.8364
# Epoch 45/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4010 - accuracy: 0.8371
# Epoch 46/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4011 - accuracy: 0.8365
# Epoch 47/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4006 - accuracy: 0.8368
# Epoch 48/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4009 - accuracy: 0.8353
# Epoch 49/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.4006 - accuracy: 0.8363
# Epoch 50/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4006 - accuracy: 0.8369
# Epoch 51/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4003 - accuracy: 0.8372
# Epoch 52/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4001 - accuracy: 0.8361
# Epoch 53/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4004 - accuracy: 0.8360
# Epoch 54/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4003 - accuracy: 0.8360
# Epoch 55/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4000 - accuracy: 0.8371
# Epoch 56/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4002 - accuracy: 0.8354
# Epoch 57/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4001 - accuracy: 0.8374
# Epoch 58/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4000 - accuracy: 0.8364
# Epoch 59/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3998 - accuracy: 0.8357
# Epoch 60/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3999 - accuracy: 0.8376
# Epoch 61/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4000 - accuracy: 0.8368
# Epoch 62/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3997 - accuracy: 0.8367
# Epoch 63/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4001 - accuracy: 0.8368
# Epoch 64/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3996 - accuracy: 0.8357
# Epoch 65/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3996 - accuracy: 0.8358
# Epoch 66/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3997 - accuracy: 0.8372
# Epoch 67/100
# 7200/7200 [==============================] - 0s 56us/step - loss: 0.3999 - accuracy: 0.8360
# Epoch 68/100
# 7200/7200 [==============================] - 0s 57us/step - loss: 0.4000 - accuracy: 0.8365
# Epoch 69/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3998 - accuracy: 0.8367
# Epoch 70/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3993 - accuracy: 0.8369
# Epoch 71/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3990 - accuracy: 0.8374
# Epoch 72/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3999 - accuracy: 0.8356
# Epoch 73/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3994 - accuracy: 0.8371
# Epoch 74/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3993 - accuracy: 0.8361
# Epoch 75/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3993 - accuracy: 0.8353
# Epoch 76/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3993 - accuracy: 0.8364
# Epoch 77/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3991 - accuracy: 0.8361
# Epoch 78/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3995 - accuracy: 0.8365
# Epoch 79/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3990 - accuracy: 0.8368
# Epoch 80/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3993 - accuracy: 0.8360
# Epoch 81/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3994 - accuracy: 0.8360
# Epoch 82/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3991 - accuracy: 0.8356
# Epoch 83/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3991 - accuracy: 0.8363
# Epoch 84/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3992 - accuracy: 0.8372
# Epoch 85/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3988 - accuracy: 0.8364
# Epoch 86/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3988 - accuracy: 0.8365
# Epoch 87/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3992 - accuracy: 0.8357
# Epoch 88/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3989 - accuracy: 0.8376
# Epoch 89/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3990 - accuracy: 0.8356
# Epoch 90/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3990 - accuracy: 0.8378
# Epoch 91/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3990 - accuracy: 0.8367
# Epoch 92/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3992 - accuracy: 0.8356
# Epoch 93/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3987 - accuracy: 0.8378
# Epoch 94/100
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.3988 - accuracy: 0.8360
# Epoch 95/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3990 - accuracy: 0.8360
# Epoch 96/100
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.3990 - accuracy: 0.8375
# Epoch 97/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3989 - accuracy: 0.8363
# Epoch 98/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3987 - accuracy: 0.8374
# Epoch 99/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3987 - accuracy: 0.8381
# Epoch 100/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3987 - accuracy: 0.8360
# Epoch 1/100
# 7200/7200 [==============================] - 0s 61us/step - loss: 0.5726 - accuracy: 0.7929
# Epoch 2/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4389 - accuracy: 0.7956
# Epoch 3/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4329 - accuracy: 0.7956
# Epoch 4/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4311 - accuracy: 0.7956
# Epoch 5/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4298 - accuracy: 0.7956
# Epoch 6/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4286 - accuracy: 0.7956
# Epoch 7/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4274 - accuracy: 0.7956
# Epoch 8/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4260 - accuracy: 0.7956
# Epoch 9/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4243 - accuracy: 0.7956
# Epoch 10/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4224 - accuracy: 0.8083
# Epoch 11/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4202 - accuracy: 0.8171
# Epoch 12/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4193 - accuracy: 0.8199
# Epoch 13/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4180 - accuracy: 0.8226
# Epoch 14/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4168 - accuracy: 0.8246
# Epoch 15/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4157 - accuracy: 0.8293
# Epoch 16/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4149 - accuracy: 0.8301
# Epoch 17/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4139 - accuracy: 0.8317
# Epoch 18/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4130 - accuracy: 0.8318
# Epoch 19/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4126 - accuracy: 0.8335
# Epoch 20/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4115 - accuracy: 0.8335
# Epoch 21/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4110 - accuracy: 0.8333
# Epoch 22/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4102 - accuracy: 0.8347
# Epoch 23/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4093 - accuracy: 0.8358
# Epoch 24/100
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.4093 - accuracy: 0.8342
# Epoch 25/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.4086 - accuracy: 0.8350
# Epoch 26/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4079 - accuracy: 0.8356
# Epoch 27/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4074 - accuracy: 0.8349
# Epoch 28/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4076 - accuracy: 0.8357
# Epoch 29/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4071 - accuracy: 0.8360
# Epoch 30/100
# 7200/7200 [==============================] - 0s 54us/step - loss: 0.4070 - accuracy: 0.8353
# Epoch 31/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4065 - accuracy: 0.8344
# Epoch 32/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4062 - accuracy: 0.8347
# Epoch 33/100
# 7200/7200 [==============================] - 0s 54us/step - loss: 0.4061 - accuracy: 0.8354
# Epoch 34/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4056 - accuracy: 0.8353
# Epoch 35/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4055 - accuracy: 0.8350
# Epoch 36/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4055 - accuracy: 0.8360
# Epoch 37/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4050 - accuracy: 0.8371
# Epoch 38/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4049 - accuracy: 0.8358
# Epoch 39/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4047 - accuracy: 0.8351
# Epoch 40/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4046 - accuracy: 0.8353
# Epoch 41/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4043 - accuracy: 0.8358
# Epoch 42/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4041 - accuracy: 0.8339
# Epoch 43/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4042 - accuracy: 0.8357
# Epoch 44/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4033 - accuracy: 0.8353
# Epoch 45/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4036 - accuracy: 0.8360
# Epoch 46/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4035 - accuracy: 0.8339
# Epoch 47/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4034 - accuracy: 0.8356
# Epoch 48/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4031 - accuracy: 0.8363
# Epoch 49/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4030 - accuracy: 0.8351
# Epoch 50/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4033 - accuracy: 0.8354
# Epoch 51/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4025 - accuracy: 0.8361
# Epoch 52/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4030 - accuracy: 0.8363
# Epoch 53/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4025 - accuracy: 0.8358
# Epoch 54/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4024 - accuracy: 0.8344
# Epoch 55/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4022 - accuracy: 0.8354
# Epoch 56/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4015 - accuracy: 0.8363
# Epoch 57/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4023 - accuracy: 0.8361
# Epoch 58/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4022 - accuracy: 0.8340
# Epoch 59/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.4018 - accuracy: 0.8351
# Epoch 60/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4017 - accuracy: 0.8354
# Epoch 61/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4015 - accuracy: 0.8361
# Epoch 62/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4015 - accuracy: 0.8351
# Epoch 63/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4016 - accuracy: 0.8363
# Epoch 64/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4012 - accuracy: 0.8354
# Epoch 65/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4012 - accuracy: 0.8336
# Epoch 66/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4010 - accuracy: 0.8342
# Epoch 67/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4010 - accuracy: 0.8358
# Epoch 68/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4008 - accuracy: 0.8353
# Epoch 69/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4006 - accuracy: 0.8358
# Epoch 70/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4007 - accuracy: 0.8358
# Epoch 71/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4005 - accuracy: 0.8351
# Epoch 72/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4005 - accuracy: 0.8376
# Epoch 73/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4004 - accuracy: 0.8350
# Epoch 74/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4007 - accuracy: 0.8361
# Epoch 75/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4001 - accuracy: 0.8364
# Epoch 76/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4003 - accuracy: 0.8363
# Epoch 77/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4000 - accuracy: 0.8363
# Epoch 78/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4002 - accuracy: 0.8365
# Epoch 79/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4002 - accuracy: 0.8358
# Epoch 80/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4001 - accuracy: 0.8347
# Epoch 81/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3999 - accuracy: 0.8349
# Epoch 82/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3995 - accuracy: 0.8364
# Epoch 83/100
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.4001 - accuracy: 0.8360
# Epoch 84/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3995 - accuracy: 0.8360
# Epoch 85/100
# 7200/7200 [==============================] - 0s 54us/step - loss: 0.3999 - accuracy: 0.8357
# Epoch 86/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3992 - accuracy: 0.8353
# Epoch 87/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3997 - accuracy: 0.8357
# Epoch 88/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3999 - accuracy: 0.8357
# Epoch 89/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3996 - accuracy: 0.8365
# Epoch 90/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3993 - accuracy: 0.8360
# Epoch 91/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3996 - accuracy: 0.8358
# Epoch 92/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3992 - accuracy: 0.8360
# Epoch 93/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3994 - accuracy: 0.8361
# Epoch 94/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3990 - accuracy: 0.8356
# Epoch 95/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3994 - accuracy: 0.8361
# Epoch 96/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3992 - accuracy: 0.8367
# Epoch 97/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3994 - accuracy: 0.8358
# Epoch 98/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3994 - accuracy: 0.8354
# Epoch 99/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3991 - accuracy: 0.8361
# Epoch 100/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3991 - accuracy: 0.8360
# Epoch 1/100
# 7200/7200 [==============================] - 0s 61us/step - loss: 0.5482 - accuracy: 0.7971
# Epoch 2/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.4366 - accuracy: 0.7975
# Epoch 3/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4299 - accuracy: 0.7975
# Epoch 4/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4278 - accuracy: 0.7975
# Epoch 5/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4250 - accuracy: 0.7975
# Epoch 6/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4221 - accuracy: 0.7975
# Epoch 7/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4194 - accuracy: 0.8039
# Epoch 8/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4174 - accuracy: 0.8174
# Epoch 9/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4159 - accuracy: 0.8215
# Epoch 10/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4147 - accuracy: 0.8228
# Epoch 11/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4136 - accuracy: 0.8265
# Epoch 12/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4121 - accuracy: 0.8289
# Epoch 13/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4111 - accuracy: 0.8299
# Epoch 14/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4100 - accuracy: 0.8314
# Epoch 15/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4092 - accuracy: 0.8319
# Epoch 16/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4081 - accuracy: 0.8338
# Epoch 17/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4073 - accuracy: 0.8329
# Epoch 18/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4067 - accuracy: 0.8329
# Epoch 19/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4060 - accuracy: 0.8335
# Epoch 20/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4052 - accuracy: 0.8350
# Epoch 21/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4047 - accuracy: 0.8346
# Epoch 22/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4045 - accuracy: 0.8363
# Epoch 23/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4039 - accuracy: 0.8349
# Epoch 24/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4036 - accuracy: 0.8357
# Epoch 25/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4030 - accuracy: 0.8363
# Epoch 26/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4026 - accuracy: 0.8347
# Epoch 27/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4022 - accuracy: 0.8360
# Epoch 28/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4013 - accuracy: 0.8361
# Epoch 29/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4006 - accuracy: 0.8363
# Epoch 30/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3996 - accuracy: 0.8367
# Epoch 31/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3984 - accuracy: 0.8347
# Epoch 32/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3979 - accuracy: 0.8363
# Epoch 33/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3972 - accuracy: 0.8374
# Epoch 34/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3969 - accuracy: 0.8372
# Epoch 35/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3961 - accuracy: 0.8364
# Epoch 36/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3957 - accuracy: 0.8378
# Epoch 37/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3955 - accuracy: 0.8368
# Epoch 38/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3954 - accuracy: 0.8353
# Epoch 39/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3947 - accuracy: 0.8382
# Epoch 40/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3945 - accuracy: 0.8369
# Epoch 41/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3945 - accuracy: 0.8376
# Epoch 42/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3940 - accuracy: 0.8368
# Epoch 43/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3938 - accuracy: 0.8379
# Epoch 44/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3937 - accuracy: 0.8392
# Epoch 45/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3932 - accuracy: 0.8371
# Epoch 46/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3930 - accuracy: 0.8385
# Epoch 47/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3930 - accuracy: 0.8378
# Epoch 48/100
# 7200/7200 [==============================] - 0s 58us/step - loss: 0.3925 - accuracy: 0.8379
# Epoch 49/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3928 - accuracy: 0.8378
# Epoch 50/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3922 - accuracy: 0.8386
# Epoch 51/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3921 - accuracy: 0.8376
# Epoch 52/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3917 - accuracy: 0.8376
# Epoch 53/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3918 - accuracy: 0.8411
# Epoch 54/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3918 - accuracy: 0.8371
# Epoch 55/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3912 - accuracy: 0.8390
# Epoch 56/100
# 7200/7200 [==============================] - 0s 58us/step - loss: 0.3915 - accuracy: 0.8376
# Epoch 57/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3909 - accuracy: 0.8375
# Epoch 58/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3913 - accuracy: 0.8393
# Epoch 59/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3910 - accuracy: 0.8389
# Epoch 60/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3908 - accuracy: 0.8372
# Epoch 61/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3908 - accuracy: 0.8394
# Epoch 62/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3902 - accuracy: 0.8374
# Epoch 63/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3904 - accuracy: 0.8379
# Epoch 64/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3905 - accuracy: 0.8383
# Epoch 65/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3898 - accuracy: 0.8375
# Epoch 66/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3906 - accuracy: 0.8396
# Epoch 67/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3904 - accuracy: 0.8388
# Epoch 68/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3903 - accuracy: 0.8385
# Epoch 69/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3900 - accuracy: 0.8385
# Epoch 70/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3901 - accuracy: 0.8400
# Epoch 71/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3901 - accuracy: 0.8361
# Epoch 72/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3899 - accuracy: 0.8371
# Epoch 73/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3898 - accuracy: 0.8382
# Epoch 74/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3898 - accuracy: 0.8382
# Epoch 75/100
# 7200/7200 [==============================] - 0s 57us/step - loss: 0.3902 - accuracy: 0.8385
# Epoch 76/100
# 7200/7200 [==============================] - 0s 54us/step - loss: 0.3893 - accuracy: 0.8385
# Epoch 77/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3899 - accuracy: 0.8383
# Epoch 78/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3896 - accuracy: 0.8388
# Epoch 79/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3896 - accuracy: 0.8393
# Epoch 80/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3892 - accuracy: 0.8386
# Epoch 81/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3895 - accuracy: 0.8386
# Epoch 82/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3897 - accuracy: 0.8365
# Epoch 83/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3895 - accuracy: 0.8393
# Epoch 84/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3894 - accuracy: 0.8403
# Epoch 85/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3899 - accuracy: 0.8375
# Epoch 86/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3898 - accuracy: 0.8379
# Epoch 87/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3895 - accuracy: 0.8369
# Epoch 88/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3896 - accuracy: 0.8383
# Epoch 89/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3890 - accuracy: 0.8403
# Epoch 90/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3896 - accuracy: 0.8386
# Epoch 91/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3896 - accuracy: 0.8385
# Epoch 92/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3895 - accuracy: 0.8388
# Epoch 93/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3891 - accuracy: 0.8382
# Epoch 94/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3893 - accuracy: 0.8390
# Epoch 95/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3891 - accuracy: 0.8389
# Epoch 96/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3896 - accuracy: 0.8382
# Epoch 97/100
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3892 - accuracy: 0.8378
# Epoch 98/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3887 - accuracy: 0.8378
# Epoch 99/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3895 - accuracy: 0.8393
# Epoch 100/100
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3892 - accuracy: 0.8393
# Epoch 1/100
# 7200/7200 [==============================] - 0s 62us/step - loss: 0.5638 - accuracy: 0.7919
# Epoch 2/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4421 - accuracy: 0.7937
# Epoch 3/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4351 - accuracy: 0.7937
# Epoch 4/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4314 - accuracy: 0.7937
# Epoch 5/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4280 - accuracy: 0.7937
# Epoch 6/100
# 7200/7200 [==============================] - 0s 54us/step - loss: 0.4255 - accuracy: 0.7937
# Epoch 7/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4229 - accuracy: 0.8056
# Epoch 8/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4213 - accuracy: 0.8185
# Epoch 9/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4205 - accuracy: 0.8196
# Epoch 10/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4190 - accuracy: 0.8222
# Epoch 11/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4180 - accuracy: 0.8263
# Epoch 12/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4167 - accuracy: 0.8281
# Epoch 13/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4155 - accuracy: 0.8282
# Epoch 14/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4151 - accuracy: 0.8308
# Epoch 15/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4144 - accuracy: 0.8319
# Epoch 16/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4140 - accuracy: 0.8306
# Epoch 17/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4131 - accuracy: 0.8322
# Epoch 18/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4127 - accuracy: 0.8318
# Epoch 19/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4119 - accuracy: 0.8325
# Epoch 20/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4117 - accuracy: 0.8318
# Epoch 21/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4115 - accuracy: 0.8321
# Epoch 22/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4110 - accuracy: 0.8314
# Epoch 23/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4107 - accuracy: 0.8340
# Epoch 24/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4103 - accuracy: 0.8329
# Epoch 25/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4098 - accuracy: 0.8335
# Epoch 26/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4095 - accuracy: 0.8315
# Epoch 27/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4093 - accuracy: 0.8315
# Epoch 28/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4089 - accuracy: 0.8310
# Epoch 29/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4086 - accuracy: 0.8324
# Epoch 30/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4081 - accuracy: 0.8325
# Epoch 31/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4075 - accuracy: 0.8325
# Epoch 32/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4065 - accuracy: 0.8321
# Epoch 33/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4061 - accuracy: 0.8322
# Epoch 34/100
# 7200/7200 [==============================] - 0s 54us/step - loss: 0.4051 - accuracy: 0.8317
# Epoch 35/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4050 - accuracy: 0.8331
# Epoch 36/100
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.4039 - accuracy: 0.8335
# Epoch 37/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4040 - accuracy: 0.8324
# Epoch 38/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4034 - accuracy: 0.8335
# Epoch 39/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.4024 - accuracy: 0.8340
# Epoch 40/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4023 - accuracy: 0.8338
# Epoch 41/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4016 - accuracy: 0.8347
# Epoch 42/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4014 - accuracy: 0.8326
# Epoch 43/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4015 - accuracy: 0.8338
# Epoch 44/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.4008 - accuracy: 0.8336
# Epoch 45/100
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.4007 - accuracy: 0.8342
# Epoch 46/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.4004 - accuracy: 0.8342
# Epoch 47/100
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3996 - accuracy: 0.8338
# Epoch 48/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3997 - accuracy: 0.8325
# Epoch 49/100
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3993 - accuracy: 0.8346
# Epoch 50/100
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3995 - accuracy: 0.8344
# Epoch 51/100
# ...
# Epoch 149/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3613 - accuracy: 0.8471
# Epoch 150/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3610 - accuracy: 0.8446
# Epoch 151/500
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3608 - accuracy: 0.8476
# Epoch 152/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3612 - accuracy: 0.8464
# Epoch 153/500
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3609 - accuracy: 0.8462
# Epoch 154/500
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3618 - accuracy: 0.8449
# Epoch 155/500
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3611 - accuracy: 0.8449
# Epoch 156/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3612 - accuracy: 0.8458
# Epoch 157/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3602 - accuracy: 0.8464
# Epoch 158/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3607 - accuracy: 0.8450
# Epoch 159/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3607 - accuracy: 0.8465
# Epoch 160/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3612 - accuracy: 0.8451
# Epoch 161/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3608 - accuracy: 0.8465
# Epoch 162/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3605 - accuracy: 0.8468
# Epoch 163/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3596 - accuracy: 0.8485
# Epoch 164/500
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3599 - accuracy: 0.8447
# Epoch 165/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3595 - accuracy: 0.8462
# Epoch 166/500
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3596 - accuracy: 0.8474
# Epoch 167/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3597 - accuracy: 0.8469
# Epoch 168/500
# 7200/7200 [==============================] - 0s 55us/step - loss: 0.3603 - accuracy: 0.8464
# Epoch 169/500
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3591 - accuracy: 0.8478
# Epoch 170/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3595 - accuracy: 0.8476
# Epoch 171/500
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3595 - accuracy: 0.8482
# Epoch 172/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3596 - accuracy: 0.8478
# Epoch 173/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3594 - accuracy: 0.8465
# Epoch 174/500
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3588 - accuracy: 0.8467
# Epoch 175/500
# 7200/7200 [==============================] - 0s 56us/step - loss: 0.3576 - accuracy: 0.8483
# Epoch 176/500
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3593 - accuracy: 0.8453
# Epoch 177/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3587 - accuracy: 0.8486
# Epoch 178/500
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3584 - accuracy: 0.8478
# Epoch 179/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3589 - accuracy: 0.8503
# Epoch 180/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3584 - accuracy: 0.8492
# Epoch 181/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3588 - accuracy: 0.8469
# Epoch 182/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3582 - accuracy: 0.8460
# Epoch 183/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3572 - accuracy: 0.8454
# Epoch 184/500
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3582 - accuracy: 0.8472
# Epoch 185/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3578 - accuracy: 0.8492
# Epoch 186/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3579 - accuracy: 0.8469
# Epoch 187/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3576 - accuracy: 0.8489
# Epoch 188/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3575 - accuracy: 0.8490
# Epoch 189/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3580 - accuracy: 0.8465
# Epoch 190/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3566 - accuracy: 0.8479
# Epoch 191/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3570 - accuracy: 0.8489
# Epoch 192/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3568 - accuracy: 0.8485
# Epoch 193/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3574 - accuracy: 0.8497
# Epoch 194/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3573 - accuracy: 0.8485
# Epoch 195/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3569 - accuracy: 0.8499
# Epoch 196/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3573 - accuracy: 0.8478
# Epoch 197/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3568 - accuracy: 0.8496
# Epoch 198/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3568 - accuracy: 0.8504
# Epoch 199/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3570 - accuracy: 0.8478
# Epoch 200/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3571 - accuracy: 0.8482
# Epoch 201/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3569 - accuracy: 0.8485
# Epoch 202/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3561 - accuracy: 0.8482
# Epoch 203/500
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3564 - accuracy: 0.8483
# Epoch 204/500
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3553 - accuracy: 0.8492
# Epoch 205/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3565 - accuracy: 0.8524
# Epoch 206/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3561 - accuracy: 0.8482
# Epoch 207/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3566 - accuracy: 0.8500
# Epoch 208/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3556 - accuracy: 0.8483
# Epoch 209/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3565 - accuracy: 0.8483
# Epoch 210/500
# 7200/7200 [==============================] - 0s 53us/step - loss: 0.3551 - accuracy: 0.8519
# Epoch 211/500
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3557 - accuracy: 0.8499
# Epoch 212/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3549 - accuracy: 0.8494
# Epoch 213/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3557 - accuracy: 0.8506
# Epoch 214/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3551 - accuracy: 0.8521
# Epoch 215/500
# 7200/7200 [==============================] - 0s 49us/step - loss: 0.3549 - accuracy: 0.8499
# Epoch 216/500
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3563 - accuracy: 0.8494
# Epoch 217/500
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3554 - accuracy: 0.8506
# Epoch 218/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3549 - accuracy: 0.8501
# Epoch 219/500
# 7200/7200 [==============================] - 0s 51us/step - loss: 0.3552 - accuracy: 0.8507
# Epoch 220/500
# 7200/7200 [==============================] - 0s 50us/step - loss: 0.3551 - accuracy: 0.8492
# Epoch 221/500
# 7200/7200 [==============================] - 0s 48us/step - loss: 0.3547 - accuracy: 0.8494
# Epoch 222/500
# 7200/7200 [==============================] - 0s 52us/step - loss: 0.3554 - accuracy: 0.8485
# Epoch 223/500
# 7200/7200 [==============================] - 0s 47us/step - loss: 0.3551 - accuracy: 0.8490
# Epoch 224/500
# 3250/7200 [============>.................] - ETA: 0s - loss: 0.3576 - accuracy: 0.8415
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-b38a6cc88c98> in <module>()
# ----> 1 grid_search = grid_search.fit(X_train, y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, sample_weight, **kwargs)
#     207         if sample_weight is not None:
#     208             kwargs['sample_weight'] = sample_weight
# --> 209         return super(KerasClassifier, self).fit(x, y, **kwargs)
#     210
#     211     def predict(self, x, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     149         fit_args.update(kwargs)
#     150
# --> 151         history = self.model.fit(x, y, **fit_args)
#     152
#     153         return history
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3790         value = math_ops.cast(value, tensor.dtype)
#    3791       converted_inputs.append(value)
# -> 3792     outputs = self._graph_fn(*converted_inputs)
#    3793
#    3794     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1603       TypeError: For invalid positional/keyword argument combinations.
#    1604     """
# -> 1605     return self._call_impl(args, kwargs)
#    1606
#    1607   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1643       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1644           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1645     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1646
#    1647   def _filtered_call(self, args, kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
best_parameter = grid_search.best_params_
best_accuracy = grid_search.best_score_
